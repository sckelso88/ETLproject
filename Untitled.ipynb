# %%
import requests
import json
from pprint import pprint

# %%
response = requests.get("https://unogs-unogs-v1.p.rapidapi.com/aaapi.cgi?q=get%3Athe+cell-!1900,2018-!0,5-!0,10-!0-!Any-!Any-!Any-!gt100-!no&t=ns&cl=all&st=adv&ob=Relevance&p=1&sa=and",
  headers={
    "X-RapidAPI-Host": "unogs-unogs-v1.p.rapidapi.com",
    "X-RapidAPI-Key": "67457246femsh5a3a71589d4babcp12b280jsn21d1c336a039"
  }
)

# %%
response_json = response.json()
pprint(response_json)
# Out:
# {'COUNT': '8',
#  'ITEMS': [{'download': '0',
#             'image': 'https://occ-0-3451-3446.1.nflxso.net/dnm/api/v6/XsrytRUxks8BtTRf9HNlZkW2tvY/AAAABfFHd7kroM6703RbQzq6TN0tOG40gSA3ncAKF_i6c2SG6SvaQmQqMLyUpHsCYJpIRwzVY2VRqcF6iFijBQAAUOgek2c3Lv8.jpg?r=d7f',
#             'imdbid': 'tt0209958',
#             'largeimage': '',
#             'netflixid': '60001368',
#             'rating': '6.3',
#             'released': '2000',
#             'runtime': '1h47m',
#             'synopsis': 'A psychotherapist uses an experimental technique to '
#                         'step inside the unstable psyche of a comatose serial '
#                         'killer in an attempt to save his last victim.',
#             'title': 'The Cell',
#             'type': 'movie',
#             'unogsdate': '2016-12-01'},
#            {'download': '0',
# ...
